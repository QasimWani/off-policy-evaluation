# %% [markdown]
# ### perform local Q-learning

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import gym
import time
import tqdm
from collections import defaultdict


from model import Agent
import utils

# %%
#create gym environment
env_name = "Taxi-v3"
env = gym.make(env_name)
env = env.unwrapped #gets ride of TimeLimit

# %%
agent = Agent(env) #create TD agent

# %%
print(agent.env.render()) #renders the initial state
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#
# None

# %%
# obtain the estimated optimal policy and corresponding action-value function
Q_optimal, policy_optimal = utils.TD_learning(agent, 50_000, 0.1, td_type="Q")
# Out:
# Episode 50000/50000
# SUMMARY
#
# Average Reward: 5.71454
# Average Steps to completion: 14.52298
#
# *******BEFORE*******
#
# Minimum Reward attained at the end of an episode: -8429 at pos: 0
# Greatest number of steps for an episode: 2177 at position: 0
#
# *******AFTER*******
# Maximum Reward attained at an episode: 15 at position #: 244
# Fewest number of steps took for task completion: 6 at pos: 244

# %%
reward_optimal, steps_optimal = utils.run_optimal_policy(agent, Q_optimal, 1_000, td_type="Q", plot=True)
print(f"Average reward at the end of 1000 episodes: {reward_optimal.mean()}")
# Out:
# Episode 1000/1000
# Average reward at the end of 1000 episodes: 7.731

# %%
utils.save_policy(agent, "../model/x.npy") #save policy
# Out:
# Saved policy!
